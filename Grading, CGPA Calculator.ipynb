# %%
A=0
Aminor=0

Bplus=0
B=0
Bminor=0

Cplus=0
C=0
Cminor=0

Dplus=0
D=0

F=0

for a in range(1,46):
    m=float(input("Enter Marks = "))
    if m>=85:
        A=A+1
    elif m>=80 and m<85:
        Aminor=Aminor+1
    elif m>=75 and m<80:
        Bplus=Bplus+1
    elif m>=70 and m<75:
        B=B+1
    elif m>=65 and m<70:
        Bminor=Bminor+1
    elif m>=60 and m<65:
        Cplus=Cplus+1
    elif m>=55 and m<60:
        C=C+1
    elif m>=50 and m<55:
        Cminor=Cminor+1
    elif m>=45 and m<50:
        Dplus=Dplus+1
    elif m>=40 and m<45:
        D=D+1
    elif m<40:
        F=F+1
print("A",A)
print("Aminor",Aminor)

print("Bplus",Bplus)
print("B",B)
print("Bminor",Bminor)

print("Cplus",Cplus)
print("C",C)
print("Cminor",Cminor)

print("Dplus",Dplus)
print("D",D)
#print("Dminor",Dminor)

print("F",F)
# Out:
# Enter Marks = FAER
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a479b00b8a3f> in <module>
#      16
#      17 for a in range(1,46):
# ---> 18     m=float(input("Enter Marks = "))
#      19     if m>=85:
#      20         A=A+1
#
# ValueError: could not convert string to float: 'FAER'

# %%
for b in range(1000):
    nos=int(input("Enter the number of subjects = "))
    gpa=0
    ch=0
    for a in range(1,nos+1):
        g=input("Enter Grade = ")
        c=int(input("Its credit hours = "))
        if g!="WF":
            ch=ch+c
        if g=="A+" or g=="A":
            p=4
        elif g=="A-":
            p=3.7
        elif g=="B+":
            p=3.3
        elif g=="B":
            p=3
        elif g=="B-":
            p=2.7
        elif g=="C+":
            p=2.3
        elif g=="C":
            p=2
        elif g=="C-":
            p=1.7
        elif g=="D+":
            p=1.3
        elif g=="D":
            p=1
        elif g=="F":
            p=0
        else:
            p=0
        gpa=gpa+c*p
    gpa=gpa/ch
    print("Your GPA is ",gpa)
    y=input("Want to calaulate another GPA? YES/NO")
    if y=="NO":
        break
# Out:
# Enter the number of subjects = 9
# Enter Grade = A-
# Its credit hours = 3
# Enter Grade = C+
# Its credit hours = 2
# Enter Grade = B
# Its credit hours = 1
# Enter Grade = C+
# Its credit hours = 1
# Enter Grade = A
# Its credit hours = 2
# Enter Grade = A
# Its credit hours = 1
# Enter Grade = B+
# Its credit hours = 2
# Enter Grade = B
# Its credit hours = 1
# Enter Grade = A-
# Its credit hours = 3
# Your GPA is  3.35625
# Want to calaulate another GPA? YES/NOYES
# Enter the number of subjects = 9
# Enter Grade = A-
# Its credit hours = 1
# Enter Grade = B
# Its credit hours = 1
# Enter Grade = C
# Its credit hours = 1
# Enter Grade = B+
# Its credit hours = 3
# Enter Grade = B+
# Its credit hours = 1
# Enter Grade = B
# Its credit hours = 3
# Enter Grade = A-
# Its credit hours = 3
# Enter Grade = A
# Its credit hours = 2
# Enter Grade = A
# Its credit hours = 1
# Your GPA is  3.375
# Want to calaulate another GPA? YES/NOYES
# Enter the number of subjects = 8
# ...

# %%
print("Hello")
# Out:
# Hello
