# %%
import pandas as pd

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0)

# %%
df.head()
# Out:
#    case_id  provincial_case_id    age     sex      health_region province  \
# 0      NaN                   1  50-59    Male            Toronto  Ontario
# 1      NaN                   2  50-59  Female            Toronto  Ontario
# 2      NaN                   1  40-49    Male  Vancouver Coastal       BC
# 3      NaN                   3  20-29  Female   Middlesex-London  Ontario
# 4      NaN                   2  50-59  Female  Vancouver Coastal       BC
#
#   country date_report report_week has_travel_history locally_acquired  \
# 0  Canada  2020-01-25  2020-01-19                  t              NaN
# 1  Canada  2020-01-27  2020-01-26                  t              NaN
# 2  Canada  2020-01-28  2020-01-26                  t              NaN
# 3  Canada  2020-01-31  2020-01-26                  t              NaN
# 4  Canada  2020-02-04  2020-02-02                  f    Close Contact
#
#                                          case_source
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,usecols=[1,2,3,4,5,6,7,7])

# %%
df.head()
# Out:
#    provincial_case_id    age     sex      health_region province country  \
# 0                   1  50-59    Male            Toronto  Ontario  Canada
# 1                   2  50-59  Female            Toronto  Ontario  Canada
# 2                   1  40-49    Male  Vancouver Coastal       BC  Canada
# 3                   3  20-29  Female   Middlesex-London  Ontario  Canada
# 4                   2  50-59  Female  Vancouver Coastal       BC  Canada
#
#   date_report
# 0  2020-01-25
# 1  2020-01-27
# 2  2020-01-28
# 3  2020-01-31
# 4  2020-02-04

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0)

# %%
df.columns
# Out:
# Index(['case_id', 'provincial_case_id', 'age', 'sex', 'health_region',
#        'province', 'country', 'date_report', 'report_week',
#        'has_travel_history', 'locally_acquired', 'case_source'],
#       dtype='object')

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,nrows=1000)

# %%
df.head()
# Out:
#    case_id  provincial_case_id    age     sex      health_region province  \
# 0      NaN                   1  50-59    Male            Toronto  Ontario
# 1      NaN                   2  50-59  Female            Toronto  Ontario
# 2      NaN                   1  40-49    Male  Vancouver Coastal       BC
# 3      NaN                   3  20-29  Female   Middlesex-London  Ontario
# 4      NaN                   2  50-59  Female  Vancouver Coastal       BC
#
#   country date_report report_week has_travel_history locally_acquired  \
# 0  Canada  2020-01-25  2020-01-19                  t              NaN
# 1  Canada  2020-01-27  2020-01-26                  t              NaN
# 2  Canada  2020-01-28  2020-01-26                  t              NaN
# 3  Canada  2020-01-31  2020-01-26                  t              NaN
# 4  Canada  2020-02-04  2020-02-02                  f    Close Contact
#
#                                          case_source
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=None,prefix="Column",skiprows=1000)

# %%
df.head()
# Out:
#    Column0  Column1       Column2       Column3            Column4 Column5  \
# 0      NaN      310  Not Reported  Not Reported  Vancouver Coastal      BC
# 1      NaN      311  Not Reported  Not Reported  Vancouver Coastal      BC
# 2      NaN      312  Not Reported  Not Reported  Vancouver Coastal      BC
# 3      NaN      313  Not Reported  Not Reported  Vancouver Coastal      BC
# 4      NaN      314  Not Reported  Not Reported  Vancouver Coastal      BC
#
#   Column6     Column7     Column8 Column9 Column10  \
# 0  Canada  2020-03-20  2020-03-15     NaN      NaN
# 1  Canada  2020-03-20  2020-03-15     NaN      NaN
# 2  Canada  2020-03-20  2020-03-15     NaN      NaN
# 3  Canada  2020-03-20  2020-03-15     NaN      NaN
# 4  Canada  2020-03-20  2020-03-15     NaN      NaN
#
#                                             Column11
# 0  https://www.cbc.ca/news/canada/british-columbi...
# 1  https://www.cbc.ca/news/canada/british-columbi...
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,skiprows=[1,234,5,2,3])

# %%
df.head()
# Out:
#    case_id  provincial_case_id    age     sex      health_region province  \
# 0      NaN                   3  20-29  Female   Middlesex-London  Ontario
# 1      NaN                   3  30-39    Male  Vancouver Coastal       BC
# 2      NaN                   4  30-39  Female  Vancouver Coastal       BC
# 3      NaN                   5  30-39  Female           Interior       BC
# 4      NaN                   6  30-39  Female             Fraser       BC
#
#   country date_report report_week has_travel_history locally_acquired  \
# 0  Canada  2020-01-31  2020-01-26                  t              NaN
# 1  Canada  2020-02-06  2020-02-02                  t              NaN
# 2  Canada  2020-02-06  2020-02-02                  t              NaN
# 3  Canada  2020-02-14  2020-02-09                  t              NaN
# 4  Canada  2020-02-20  2020-02-16                  t              NaN
#
#                                          case_source
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,skiprows=[1,1000])

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,skiprows=[x for x in range(1,1000)])

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,index_col=1)

# %%
df.head()
# Out:
#                     case_id    age     sex      health_region province  \
# provincial_case_id
# 1                       NaN  50-59    Male            Toronto  Ontario
# 2                       NaN  50-59  Female            Toronto  Ontario
# 1                       NaN  40-49    Male  Vancouver Coastal       BC
# 3                       NaN  20-29  Female   Middlesex-London  Ontario
# 2                       NaN  50-59  Female  Vancouver Coastal       BC
#
#                    country date_report report_week has_travel_history  \
# provincial_case_id
# 1                   Canada  2020-01-25  2020-01-19                  t
# 2                   Canada  2020-01-27  2020-01-26                  t
# 1                   Canada  2020-01-28  2020-01-26                  t
# 3                   Canada  2020-01-31  2020-01-26                  t
# 2                   Canada  2020-02-04  2020-02-02                  f
#
#                    locally_acquired  \
# provincial_case_id
# ...

# %%
df.head(6)
# Out:
#                     case_id    age     sex      health_region province  \
# provincial_case_id
# 1                       NaN  50-59    Male            Toronto  Ontario
# 2                       NaN  50-59  Female            Toronto  Ontario
# 1                       NaN  40-49    Male  Vancouver Coastal       BC
# 3                       NaN  20-29  Female   Middlesex-London  Ontario
# 2                       NaN  50-59  Female  Vancouver Coastal       BC
# 3                       NaN  30-39    Male  Vancouver Coastal       BC
#
#                    country date_report report_week has_travel_history  \
# provincial_case_id
# 1                   Canada  2020-01-25  2020-01-19                  t
# 2                   Canada  2020-01-27  2020-01-26                  t
# 1                   Canada  2020-01-28  2020-01-26                  t
# 3                   Canada  2020-01-31  2020-01-26                  t
# 2                   Canada  2020-02-04  2020-02-02                  f
# ...

# %%
df.tail(6)
# Out:
#                     case_id           age           sex health_region  \
# provincial_case_id
# 16332                   NaN         40-49          Male   Thunder Bay
# 16333                   NaN         40-49          Male   Thunder Bay
# 16334                   NaN  Not Reported  Not Reported  Peterborough
# 16335                   NaN  Not Reported  Not Reported  Peterborough
# 16336                   NaN  Not Reported  Not Reported  Peterborough
# 16337                   NaN  Not Reported  Not Reported       Sudbury
#
#                    province country date_report report_week  \
# provincial_case_id
# 16332               Ontario  Canada  2020-04-28  2020-04-26
# 16333               Ontario  Canada  2020-04-28  2020-04-26
# 16334               Ontario  Canada  2020-04-28  2020-04-26
# 16335               Ontario  Canada  2020-04-28  2020-04-26
# 16336               Ontario  Canada  2020-04-28  2020-04-26
# 16337               Ontario  Canada  2020-04-28  2020-04-26
#
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,keep_default_na=False)

# %%
df.head(4)
# Out:
#   case_id  provincial_case_id    age     sex      health_region province  \
# 0                           1  50-59    Male            Toronto  Ontario
# 1                           2  50-59  Female            Toronto  Ontario
# 2                           1  40-49    Male  Vancouver Coastal       BC
# 3                           3  20-29  Female   Middlesex-London  Ontario
#
#   country date_report report_week has_travel_history locally_acquired  \
# 0  Canada  2020-01-25  2020-01-19                  t
# 1  Canada  2020-01-27  2020-01-26                  t
# 2  Canada  2020-01-28  2020-01-26                  t
# 3  Canada  2020-01-31  2020-01-26                  t
#
#                                          case_source
# 0  (1) https://news.ontario.ca/mohltc/en/2020/01/...
# 1  (1) https://news.ontario.ca/mohltc/en/2020/01/...
# 2  https://news.gov.bc.ca/releases/2020HLTH0015-0...
# 3  (1) https://news.ontario.ca/mohltc/en/2020/01/...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,usecols=[x for x in range(1,10)])

# %%
df
# Out:
#        provincial_case_id           age           sex      health_region  \
# 0                       1         50-59          Male            Toronto
# 1                       2         50-59        Female            Toronto
# 2                       1         40-49          Male  Vancouver Coastal
# 3                       3         20-29        Female   Middlesex-London
# 4                       2         50-59        Female  Vancouver Coastal
# 5                       3         30-39          Male  Vancouver Coastal
# 6                       4         30-39        Female  Vancouver Coastal
# 7                       5         30-39        Female           Interior
# 8                       6         30-39        Female             Fraser
# 9                       4         20-29        Female            Toronto
# 10                      5         60-69        Female            Toronto
# 11                      7         40-49          Male             Fraser
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,na_values=False)

# %%
df.head(2)
# Out:
#    case_id  provincial_case_id    age     sex health_region province country  \
# 0      NaN                   1  50-59    Male       Toronto  Ontario  Canada
# 1      NaN                   2  50-59  Female       Toronto  Ontario  Canada
#
#   date_report report_week has_travel_history locally_acquired  \
# 0  2020-01-25  2020-01-19                  t              NaN
# 1  2020-01-27  2020-01-26                  t              NaN
#
#                                          case_source
# 0  (1) https://news.ontario.ca/mohltc/en/2020/01/...
# 1  (1) https://news.ontario.ca/mohltc/en/2020/01/...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,na_values=True)

# %%
df.head(3)
# Out:
#    case_id  provincial_case_id    age     sex      health_region province  \
# 0      NaN                 NaN  50-59    Male            Toronto  Ontario
# 1      NaN                 2.0  50-59  Female            Toronto  Ontario
# 2      NaN                 NaN  40-49    Male  Vancouver Coastal       BC
#
#   country date_report report_week has_travel_history locally_acquired  \
# 0  Canada  2020-01-25  2020-01-19                  t              NaN
# 1  Canada  2020-01-27  2020-01-26                  t              NaN
# 2  Canada  2020-01-28  2020-01-26                  t              NaN
#
#                                          case_source
# 0  (1) https://news.ontario.ca/mohltc/en/2020/01/...
# 1  (1) https://news.ontario.ca/mohltc/en/2020/01/...
# 2  https://news.gov.bc.ca/releases/2020HLTH0015-0...

# %%
df.isnull()
# Out:
#        case_id  provincial_case_id    age    sex  health_region  province  \
# 0         True                True  False  False          False     False
# 1         True               False  False  False          False     False
# 2         True                True  False  False          False     False
# 3         True               False  False  False          False     False
# 4         True               False  False  False          False     False
# 5         True               False  False  False          False     False
# 6         True               False  False  False          False     False
# 7         True               False  False  False          False     False
# 8         True               False  False  False          False     False
# 9         True               False  False  False          False     False
# 10        True               False  False  False          False     False
# 11        True               False  False  False          False     False
# ...

# %%
df.notnull()
# Out:
#        case_id  provincial_case_id   age   sex  health_region  province  \
# 0        False               False  True  True           True      True
# 1        False                True  True  True           True      True
# 2        False               False  True  True           True      True
# 3        False                True  True  True           True      True
# 4        False                True  True  True           True      True
# 5        False                True  True  True           True      True
# 6        False                True  True  True           True      True
# 7        False                True  True  True           True      True
# 8        False                True  True  True           True      True
# 9        False                True  True  True           True      True
# 10       False                True  True  True           True      True
# 11       False                True  True  True           True      True
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0)

# %%
df.head()
# Out:
#    case_id  provincial_case_id    age     sex      health_region province  \
# 0      NaN                   1  50-59    Male            Toronto  Ontario
# 1      NaN                   2  50-59  Female            Toronto  Ontario
# 2      NaN                   1  40-49    Male  Vancouver Coastal       BC
# 3      NaN                   3  20-29  Female   Middlesex-London  Ontario
# 4      NaN                   2  50-59  Female  Vancouver Coastal       BC
#
#   country date_report report_week has_travel_history locally_acquired  \
# 0  Canada  2020-01-25  2020-01-19                  t              NaN
# 1  Canada  2020-01-27  2020-01-26                  t              NaN
# 2  Canada  2020-01-28  2020-01-26                  t              NaN
# 3  Canada  2020-01-31  2020-01-26                  t              NaN
# 4  Canada  2020-02-04  2020-02-02                  f    Close Contact
#
#                                          case_source
# ...

# %%
df.isnull().sum()
# Out:
# case_id               50982
# provincial_case_id        0
# age                       0
# sex                       0
# health_region             0
# province                  0
# country                   0
# date_report               0
# report_week               0
# has_travel_history    49832
# locally_acquired      50408
# case_source               0
# dtype: int64

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0)

# %%
df.tail(2)
# Out:
#        case_id  provincial_case_id           age           sex health_region  \
# 50980      NaN               16336  Not Reported  Not Reported  Peterborough
# 50981      NaN               16337  Not Reported  Not Reported       Sudbury
#
#       province country date_report report_week has_travel_history  \
# 50980  Ontario  Canada  2020-04-28  2020-04-26                NaN
# 50981  Ontario  Canada  2020-04-28  2020-04-26                NaN
#
#       locally_acquired                                        case_source
# 50980              NaN  https://www.peterboroughpublichealth.ca/your-h...
# 50981              NaN  https://www.phsd.ca/health-topics-programs/dis...

# %%
df.notnull().sum()
# Out:
# case_id                   0
# provincial_case_id    50982
# age                   50982
# sex                   50982
# health_region         50982
# province              50982
# country               50982
# date_report           50982
# report_week           50982
# has_travel_history     1150
# locally_acquired        574
# case_source           50982
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [case_id, provincial_case_id, age, sex, health_region, province, country, date_report, report_week, has_travel_history, locally_acquired, case_source]
# Index: []

# %%
d=df.dropna(axis=1)

# %%
d.columns
# Out:
# Index(['provincial_case_id', 'age', 'sex', 'health_region', 'province',
#        'country', 'date_report', 'report_week', 'case_source'],
#       dtype='object')

# %%
df.dropna(how="all",axis=1)
# Out:
#        provincial_case_id           age           sex      health_region  \
# 0                       1         50-59          Male            Toronto
# 1                       2         50-59        Female            Toronto
# 2                       1         40-49          Male  Vancouver Coastal
# 3                       3         20-29        Female   Middlesex-London
# 4                       2         50-59        Female  Vancouver Coastal
# 5                       3         30-39          Male  Vancouver Coastal
# 6                       4         30-39        Female  Vancouver Coastal
# 7                       5         30-39        Female           Interior
# 8                       6         30-39        Female             Fraser
# 9                       4         20-29        Female            Toronto
# 10                      5         60-69        Female            Toronto
# 11                      7         40-49          Male             Fraser
# ...

# %%
df.dropna(thresh=2)#true values
# Out:
#        case_id  provincial_case_id           age           sex  \
# 0          NaN                   1         50-59          Male
# 1          NaN                   2         50-59        Female
# 2          NaN                   1         40-49          Male
# 3          NaN                   3         20-29        Female
# 4          NaN                   2         50-59        Female
# 5          NaN                   3         30-39          Male
# 6          NaN                   4         30-39        Female
# 7          NaN                   5         30-39        Female
# 8          NaN                   6         30-39        Female
# 9          NaN                   4         20-29        Female
# 10         NaN                   5         60-69        Female
# 11         NaN                   7         40-49          Male
# 12         NaN                   6         60-69          Male
# 13         NaN                   1         40-49        Female
# ...

# %%
df.dropna(subset=["health_region"])
# Out:
#        case_id  provincial_case_id           age           sex  \
# 0          NaN                   1         50-59          Male
# 1          NaN                   2         50-59        Female
# 2          NaN                   1         40-49          Male
# 3          NaN                   3         20-29        Female
# 4          NaN                   2         50-59        Female
# 5          NaN                   3         30-39          Male
# 6          NaN                   4         30-39        Female
# 7          NaN                   5         30-39        Female
# 8          NaN                   6         30-39        Female
# 9          NaN                   4         20-29        Female
# 10         NaN                   5         60-69        Female
# 11         NaN                   7         40-49          Male
# 12         NaN                   6         60-69          Male
# 13         NaN                   1         40-49        Female
# ...

# %%
df.dropna(axis=1,how="all",inplace=True)

# %%
df
# Out:
#        provincial_case_id           age           sex      health_region  \
# 0                       1         50-59          Male            Toronto
# 1                       2         50-59        Female            Toronto
# 2                       1         40-49          Male  Vancouver Coastal
# 3                       3         20-29        Female   Middlesex-London
# 4                       2         50-59        Female  Vancouver Coastal
# 5                       3         30-39          Male  Vancouver Coastal
# 6                       4         30-39        Female  Vancouver Coastal
# 7                       5         30-39        Female           Interior
# 8                       6         30-39        Female             Fraser
# 9                       4         20-29        Female            Toronto
# 10                      5         60-69        Female            Toronto
# 11                      7         40-49          Male             Fraser
# ...

# %%
df.replace("Not Reported",None)
# Out:
#        provincial_case_id    age     sex      health_region province country  \
# 0                       1  50-59    Male            Toronto  Ontario  Canada
# 1                       2  50-59  Female            Toronto  Ontario  Canada
# 2                       1  40-49    Male  Vancouver Coastal       BC  Canada
# 3                       3  20-29  Female   Middlesex-London  Ontario  Canada
# 4                       2  50-59  Female  Vancouver Coastal       BC  Canada
# 5                       3  30-39    Male  Vancouver Coastal       BC  Canada
# 6                       4  30-39  Female  Vancouver Coastal       BC  Canada
# 7                       5  30-39  Female           Interior       BC  Canada
# 8                       6  30-39  Female             Fraser       BC  Canada
# 9                       4  20-29  Female            Toronto  Ontario  Canada
# 10                      5  60-69  Female            Toronto  Ontario  Canada
# ...

# %%
df.isnull().sum()
# Out:
# provincial_case_id        0
# age                       0
# sex                       0
# health_region             0
# province                  0
# country                   0
# date_report               0
# report_week               0
# has_travel_history    49832
# locally_acquired      50408
# case_source               0
# dtype: int64

# %%
df.replace(to_replace="Not_Reported",value="NaN")
# Out:
#        provincial_case_id           age           sex      health_region  \
# 0                       1         50-59          Male            Toronto
# 1                       2         50-59        Female            Toronto
# 2                       1         40-49          Male  Vancouver Coastal
# 3                       3         20-29        Female   Middlesex-London
# 4                       2         50-59        Female  Vancouver Coastal
# 5                       3         30-39          Male  Vancouver Coastal
# 6                       4         30-39        Female  Vancouver Coastal
# 7                       5         30-39        Female           Interior
# 8                       6         30-39        Female             Fraser
# 9                       4         20-29        Female            Toronto
# 10                      5         60-69        Female            Toronto
# 11                      7         40-49          Male             Fraser
# ...

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",usecols=[3,4,5,6,7])

# %%
df.head(4)
# Out:
#       sex      health_region province country date_report
# 0    Male            Toronto  Ontario  Canada  2020-01-25
# 1  Female            Toronto  Ontario  Canada  2020-01-27
# 2    Male  Vancouver Coastal       BC  Canada  2020-01-28
# 3  Female   Middlesex-London  Ontario  Canada  2020-01-31

# %%
df.tail(5)
# Out:
#                 sex health_region province country date_report
# 50977          Male   Thunder Bay  Ontario  Canada  2020-04-28
# 50978  Not Reported  Peterborough  Ontario  Canada  2020-04-28
# 50979  Not Reported  Peterborough  Ontario  Canada  2020-04-28
# 50980  Not Reported  Peterborough  Ontario  Canada  2020-04-28
# 50981  Not Reported       Sudbury  Ontario  Canada  2020-04-28

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,na_values={"sex":"Not Reported","age":"Not Reported"})

# %%
df
# Out:
#        case_id  provincial_case_id    age     sex      health_region province  \
# 0          NaN                   1  50-59    Male            Toronto  Ontario
# 1          NaN                   2  50-59  Female            Toronto  Ontario
# 2          NaN                   1  40-49    Male  Vancouver Coastal       BC
# 3          NaN                   3  20-29  Female   Middlesex-London  Ontario
# 4          NaN                   2  50-59  Female  Vancouver Coastal       BC
# 5          NaN                   3  30-39    Male  Vancouver Coastal       BC
# 6          NaN                   4  30-39  Female  Vancouver Coastal       BC
# 7          NaN                   5  30-39  Female           Interior       BC
# 8          NaN                   6  30-39  Female             Fraser       BC
# 9          NaN                   4  20-29  Female            Toronto  Ontario
# 10         NaN                   5  60-69  Female            Toronto  Ontario
# ...

# %%
df.tail(4)
# Out:
#        case_id  provincial_case_id  age  sex health_region province country  \
# 50978      NaN               16334  NaN  NaN  Peterborough  Ontario  Canada
# 50979      NaN               16335  NaN  NaN  Peterborough  Ontario  Canada
# 50980      NaN               16336  NaN  NaN  Peterborough  Ontario  Canada
# 50981      NaN               16337  NaN  NaN       Sudbury  Ontario  Canada
#
#       date_report report_week has_travel_history locally_acquired  \
# 50978  2020-04-28  2020-04-26                NaN              NaN
# 50979  2020-04-28  2020-04-26                NaN              NaN
# 50980  2020-04-28  2020-04-26                NaN              NaN
# 50981  2020-04-28  2020-04-26                NaN              NaN
#
#                                              case_source
# 50978  https://www.peterboroughpublichealth.ca/your-h...
# 50979  https://www.peterboroughpublichealth.ca/your-h...
# 50980  https://www.peterboroughpublichealth.ca/your-h...
# ...

# %%
df.isnull().sum()
# Out:
# case_id               50982
# provincial_case_id        0
# age                   49521
# sex                   49658
# health_region             0
# province                  0
# country                   0
# date_report               0
# report_week               0
# has_travel_history    49832
# locally_acquired      50408
# case_source               0
# dtype: int64

# %%
df= pd.read_csv("public-covid-19-cases-canada-Copy1.csv",header=0,keep_default_na=False)

# %%
df
# Out:
#       case_id  provincial_case_id           age           sex  \
# 0                               1         50-59          Male
# 1                               2         50-59        Female
# 2                               1         40-49          Male
# 3                               3         20-29        Female
# 4                               2         50-59        Female
# 5                               3         30-39          Male
# 6                               4         30-39        Female
# 7                               5         30-39        Female
# 8                               6         30-39        Female
# 9                               4         20-29        Female
# 10                              5         60-69        Female
# 11                              7         40-49          Male
# 12                              6         60-69          Male
# 13                              1         40-49        Female
# ...
