# %%
def summ(a,b):
    su=0
    for at in range(a,b):
        if at%4==0:
            n=366
        else:
            n=365
        su+=n
    return su

# %%
def year(a):
    nn=0
    if a<2020:
        sum=summ(a,2020)
        nn=sum%7
    tt=[31,29,31,30,31,30,31,31,30,31,30,31]
    if a%4!=0:
        tt[1]=28
    mm=["Monday","Tuesday","Wednesday",
        "Thursday","Friday",
        "Saturday","Sunday"]
    dd={}
    p=nn-2
    if p==0:
        i=0
    elif p==1:
        i=6
    elif p==2:
        i=5
    elif p==3:
        i=4
    elif p==4:
        i=3
    elif p==-2:
        i=2
    elif p==-1:
        i=1
    else:
        i=0
        print("There is an error in this code.")
    if a>2020:
        ss=summ(2020,a)
        np=ss%7
        for sa in range(0,7):
            if np==sa:
                i=np+2
            if np==5:
                i=0
            if np==6:
                i=1
    t=0
    for aaa in tt:
        for v in range(1,aaa+1):
            b=str(v)+"/"+str(t+1)+"/"+str(a)
            dd[b]=mm[i]
           # with open("Calender.txt","a")as s:
            #    pp=b+" "+mm[i]+"\n"
             #   s.write(pp)
            i+=1
            if i==7:
                i=0
        t+=1
    return dd

# %%
GrandList=[]
for aa in range(2015,2025):
    dmy=year(aa)
    GrandList.append(dmy)
print(GrandList[5]["15/2/2020"])
# Out:
# Saturday

# %%
print(GrandList)
# Out:
# [{'1/1/2015': 'Thursday', '2/1/2015': 'Friday', '3/1/2015': 'Saturday', '4/1/2015': 'Sunday', '5/1/2015': 'Monday', '6/1/2015': 'Tuesday', '7/1/2015': 'Wednesday', '8/1/2015': 'Thursday', '9/1/2015': 'Friday', '10/1/2015': 'Saturday', '11/1/2015': 'Sunday', '12/1/2015': 'Monday', '13/1/2015': 'Tuesday', '14/1/2015': 'Wednesday', '15/1/2015': 'Thursday', '16/1/2015': 'Friday', '17/1/2015': 'Saturday', '18/1/2015': 'Sunday', '19/1/2015': 'Monday', '20/1/2015': 'Tuesday', '21/1/2015': 'Wednesday', '22/1/2015': 'Thursday', '23/1/2015': 'Friday', '24/1/2015': 'Saturday', '25/1/2015': 'Sunday', '26/1/2015': 'Monday', '27/1/2015': 'Tuesday', '28/1/2015': 'Wednesday', '29/1/2015': 'Thursday', '30/1/2015': 'Friday', '31/1/2015': 'Saturday', '1/2/2015': 'Sunday', '2/2/2015': 'Monday', '3/2/2015': 'Tuesday', '4/2/2015': 'Wednesday', '5/2/2015': 'Thursday', '6/2/2015': 'Friday', '7/2/2015': 'Saturday', '8/2/2015': 'Sunday', '9/2/2015': 'Monday', '10/2/2015': 'Tuesday', '11/2/2015': 'Wednesday', 
# ...
